# %%
import json

file=open('weather.json')
data=json.load(file)
backup=data

# %%
len(data)
# Out:
# 366

# %%
len(data[0])
# Out:
# 22

# %%
type(data)
# Out:
# list

# %%
data[1]
# Out:
# {'MinTemp': 14,
#  'MaxTemp': 26.9,
#  'Rainfall': 3.6,
#  'Evaporation': 4.4,
#  'Sunshine': 9.7,
#  'WindGustDir': 'ENE',
#  'WindGustSpeed': 39,
#  'WindDir9am': 'E',
#  'WindDir3pm': 'W',
#  'WindSpeed9am': 4,
#  'WindSpeed3pm': 17,
#  'Humidity9am': 80,
#  'Humidity3pm': 36,
#  'Pressure9am': 1012.4,
#  'Pressure3pm': 1008.4,
#  'Cloud9am': 5,
#  'Cloud3pm': 3,
#  'Temp9am': 17.5,
#  'Temp3pm': 25.7,
#  'RainToday': 'Yes',
#  'RISK_MM': 3.6,
#  'RainTomorrow': 'Yes'}

# %%
temp_gt_25=[x for x in data if x["MaxTemp"]>=25]

# %%
temp_gt_25
# Out:
# [{'MinTemp': 14,
#   'MaxTemp': 26.9,
#   'Rainfall': 3.6,
#   'Evaporation': 4.4,
#   'Sunshine': 9.7,
#   'WindGustDir': 'ENE',
#   'WindGustSpeed': 39,
#   'WindDir9am': 'E',
#   'WindDir3pm': 'W',
#   'WindSpeed9am': 4,
#   'WindSpeed3pm': 17,
#   'Humidity9am': 80,
#   'Humidity3pm': 36,
#   'Pressure9am': 1012.4,
#   'Pressure3pm': 1008.4,
#   'Cloud9am': 5,
#   'Cloud3pm': 3,
#   'Temp9am': 17.5,
#   'Temp3pm': 25.7,
#   'RainToday': 'Yes',
#   'RISK_MM': 3.6,
#   'RainTomorrow': 'Yes'},
#  {'MinTemp': 9.1,
#   'MaxTemp': 25.2,
#   'Rainfall': 0,
#   'Evaporation': 4.2,
#   'Sunshine': 11.9,
#   'WindGustDir': 'N',
#   'WindGustSpeed': 30,
#   'WindDir9am': 'SE',
#   'WindDir3pm': 'NW',
#   'WindSpeed9am': 6,
#   'WindSpeed3pm': 9,
#   'Humidity9am': 74,
#   'Humidity3pm': 34,
#   'Pressure9am': 1024.4,
#   'Pressure3pm': 1021.1,
#   'Cloud9am': 1,
#   'Cloud3pm': 2,
#   'Temp9am': 14.6,
#   'Temp3pm': 24,
#   'RainToday': 'No',
#   'RISK_MM': 0.2,
#   'RainTomorrow': 'No'},
# ...

# %%
len(temp_gt_25)
# Out:
# 98

# %%
for i in temp_gt_25:
    print(i["MaxTemp"])
# Out:
# 26.9
# 25.2
# 27.3
# 27.9
# 30.9
# 31.2
# 32.1
# 31.2
# 30
# 32.3
# 33.4
# 33.4
# 28.4
# 26.9
# 28
# 26.3
# 26.5
# 26.8
# 25.8
# 28.2
# 29.4
# 27.1
# 29.9
# 29.5
# 26.3
# 26.7
# 28.3
# 31.6
# 35
# 33.5
# 34.2
# 35
# 25.3
# 27.5
# 34.1
# 33.9
# 30.3
# 29.9
# 34.2
# 35.8
# 35.7
# 33.8
# 33.8
# 33.2
# 25.1
# 27.8
# 25.7
# 28.8
# 31.3
# 33.2
# 33.9
# 34.9
# 27.8
# 28.8
# 29.6
# 27.4
# 26
# 25.2
# 26.1
# 25.8
# 27.1
# 28.9
# 28.6
# 25.1
# 25.9
# 28.2
# 27.6
# 27.3
# 28.2
# 27.6
# 31.8
# 29.2
# 27.4
# 27.8
# 31.7
# 34.7
# 31.7
# 33.1
# 33.8
# 35.2
# 32.3
# 30.2
# 29.9
# 26.2
# 29.3
# 25.5
# 25.7
# 27.6
# 28.9
# 26.1
# 28.5
# 27.4
# 25.5
# 26.1
# 30.7
# 28.4
# 26.9
# 30.2

# %%
sorted_temp=sorted(temp_gt_25, key=lambda x: x['MaxTemp'])

# %%
for i in sorted_temp:
    print(i['MaxTemp'])
# Out:
# 25.1
# 25.1
# 25.2
# 25.2
# 25.3
# 25.5
# 25.5
# 25.7
# 25.7
# 25.8
# 25.8
# 25.9
# 26
# 26.1
# 26.1
# 26.1
# 26.2
# 26.3
# 26.3
# 26.5
# 26.7
# 26.8
# 26.9
# 26.9
# 26.9
# 27.1
# 27.1
# 27.3
# 27.3
# 27.4
# 27.4
# 27.4
# 27.5
# 27.6
# 27.6
# 27.6
# 27.8
# 27.8
# 27.8
# 27.9
# 28
# 28.2
# 28.2
# 28.2
# 28.3
# 28.4
# 28.4
# 28.5
# 28.6
# 28.8
# 28.8
# 28.9
# 28.9
# 29.2
# 29.3
# 29.4
# 29.5
# 29.6
# 29.9
# 29.9
# 29.9
# 30
# 30.2
# 30.2
# 30.3
# 30.7
# 30.9
# 31.2
# 31.2
# 31.3
# 31.6
# 31.7
# 31.7
# 31.8
# 32.1
# 32.3
# 32.3
# 33.1
# 33.2
# 33.2
# 33.4
# 33.4
# 33.5
# 33.8
# 33.8
# 33.8
# 33.9
# 33.9
# 34.1
# 34.2
# 34.2
# 34.7
# 34.9
# 35
# 35
# 35.2
# 35.7
# 35.8

# %%
avg_gt_25=sum(x['MaxTemp'] for x in sorted_temp)/len(sorted_temp)
avg_gt_25
# Out:
# 29.453061224489804

# %%
for i in temp_gt_25:
    i["MaxTempFahrenheit"]=i['MaxTemp']* 9/5 + 32
    
temp_gt_25
# Out:
# [{'MinTemp': 14,
#   'MaxTemp': 26.9,
#   'Rainfall': 3.6,
#   'Evaporation': 4.4,
#   'Sunshine': 9.7,
#   'WindGustDir': 'ENE',
#   'WindGustSpeed': 39,
#   'WindDir9am': 'E',
#   'WindDir3pm': 'W',
#   'WindSpeed9am': 4,
#   'WindSpeed3pm': 17,
#   'Humidity9am': 80,
#   'Humidity3pm': 36,
#   'Pressure9am': 1012.4,
#   'Pressure3pm': 1008.4,
#   'Cloud9am': 5,
#   'Cloud3pm': 3,
#   'Temp9am': 17.5,
#   'Temp3pm': 25.7,
#   'RainToday': 'Yes',
#   'RISK_MM': 3.6,
#   'RainTomorrow': 'Yes',
#   'MaxTempFahrenheit': 80.42},
#  {'MinTemp': 9.1,
#   'MaxTemp': 25.2,
#   'Rainfall': 0,
#   'Evaporation': 4.2,
#   'Sunshine': 11.9,
#   'WindGustDir': 'N',
#   'WindGustSpeed': 30,
#   'WindDir9am': 'SE',
#   'WindDir3pm': 'NW',
#   'WindSpeed9am': 6,
#   'WindSpeed3pm': 9,
#   'Humidity9am': 74,
#   'Humidity3pm': 34,
#   'Pressure9am': 1024.4,
#   'Pressure3pm': 1021.1,
#   'Cloud9am': 1,
#   'Cloud3pm': 2,
#   'Temp9am': 14.6,
#   'Temp3pm': 24,
#   'RainToday': 'No',
# ...
